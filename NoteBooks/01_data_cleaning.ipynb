# %%
import pandas as pd

customers = pd.read_csv("../data/raw/customers.csv")
products = pd.read_csv("../data/raw/products.csv")
orders = pd.read_csv("../data/raw/orders.csv")
order_items = pd.read_csv("../data/raw/order_items.csv")

customers.head(), products.head(), orders.head(), order_items.head()
# Out:
# (   customer_id     customer_name  gender  age         city      state  segment
#  0            1    Shelly Schultz  Female   32  Maharashtra       Pune    Loyal
#  1            2       Amanda Clay    Male   36   Tamil Nadu    Chennai    Loyal
#  2            3  Stephanie Becker    Male   24    Telangana  Hyderabad  Regular
#  3            4    Kristina Smith    Male   27    Karnataka  Bangalore    Loyal
#  4            5        Carl Lucas    Male   29  West Bengal    Kolkata    Loyal,
#     product_id   product_name         category   sub_category  unit_price
#  0           1     Smartphone      Electronics     Smartphone       15634
#  1           2         Laptop      Electronics         Laptop       38685
#  2           3     Headphones      Electronics     Headphones        7218
#  3           4     Smartwatch      Electronics     Smartwatch        4502
#  4           5  Mixer Grinder  Home Appliances  Mixer Grinder         650,
#     order_id  customer_id  order_date    payment_method order_status
#  0         1          762  2024-07-04        Debit Card    Delivered
#  1         2          724  2024-10-27       Credit Card    Delivered
#  2         3          932  2025-02-10  Cash on Delivery    Delivered
#  3         4          228  2024-09-05               UPI     Returned
#  4         5          325  2024-10-16       Credit Card     Returned,
#     order_item_id  order_id  product_id  quantity  unit_price  total_price
#  0              1         1           3         1        7218         7218
#  1              2         1          10         2       15153        30306
#  2              3         2           5         1         650          650
#  3              4         2           2         2       38685        77370
#  4              5         2          11         1        1486         1486)

# %%
customers.shape, products.shape, orders.shape, order_items.shape
# Out:
# ((1000, 7), (16, 5), (5000, 5), (12312, 6))

# %%
customers.isnull().sum()
products.isnull().sum()
orders.isnull().sum()
order_items.isnull().sum()
# Out:
# order_item_id    0
# order_id         0
# product_id       0
# quantity         0
# unit_price       0
# total_price      0
# dtype: int64

# %%
customers.duplicated().sum()
products.duplicated().sum()
orders.duplicated().sum()
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.dtypes
products.dtypes
orders.dtypes
order_items.dtypes
# Out:
# order_item_id    int64
# order_id         int64
# product_id       int64
# quantity         int64
# unit_price       int64
# total_price      int64
# dtype: object

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
customers.shape, products.shape, orders.shape, order_items.shape
# Out:
# ((1000, 7), (16, 5), (5000, 5), (12312, 6))
